# %% [markdown]
# # Build the data catalog

# %% [markdown]
# ## Imports

# %%
from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_timeseries

# %% [markdown]
# ## Setup the Builder

# %%
b = Builder(
    # Where to look for model output
    "/glade/campaign/cesm/development/wawg/WACCM6-TSMLT-GEO/SAI1/",
    exclude_patterns=["*/hist/*", "*/rest/*"],
    njobs=-1,
)

# %% [markdown]
# ## Build the Catalog

# %%
b= b.build(parse_cesm_timeseries)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 420 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=-1)]: Done 744 tasks      | elapsed:   39.1s
# [Parallel(n_jobs=-1)]: Done 1140 tasks      | elapsed:   56.8s
# [Parallel(n_jobs=-1)]: Done 1608 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 2148 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 2760 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 3444 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 4200 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done 5028 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 5928 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 6900 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 7944 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 9176 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 10364 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 11624 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 12956 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 14360 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 15836 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 17384 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 19004 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 20696 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 22460 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 24296 tasks      | elapsed: 20.7min
# [Parallel(n_jobs=-1)]: Done 26204 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=-1)]: Done 28184 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 30406 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 32530 tasks      | elapsed: 27.8min
# [Parallel(n_jobs=-1)]: Done 32557 out of 32560 | elapsed: 27.8min remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 32560 out of 32560 | elapsed: 27.9min finished
# /glade/work/dbailey/miniconda3/envs/silverlinings-diagnostics-dev/lib/python3.9/site-packages/ecgtools/builder.py:179: UserWarning: Unable to parse 501 assets/files. A list of these assets can be found in `.invalid_assets` attribute.
#   self.get_directories().get_filelist()._parse(

# %%
b.df
# Out:
#       component   stream                                             case  \
# 0           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 1           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 2           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 3           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 4           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# ...         ...      ...                                              ...
# 32555       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 32556       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 32557       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 32558       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 32559       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
#
#        member_id  variable     start_time       end_time  \
# 0            6.0        TS  2045-01-01T00  2055-01-01T00
# 1            6.0  PM25_SRF  2045-01-01T00  2055-01-01T00
# 2            6.0     PRECT  2055-01-01T00  2065-01-01T00
# 3            6.0     f107p  2055-01-01T00  2065-01-01T00
# 4            6.0      f107  2055-01-01T00  2065-01-01T00
# ...          ...       ...            ...            ...
# 32555        2.0  congel_d     2035-01-01     2069-12-31
# 32556        2.0  frazil_d     2035-01-01     2069-12-31
# 32557        2.0  daidtt_d     2035-01-01     2069-12-31
# 32558        2.0   meltb_d     2035-01-01     2069-12-31
# 32559        2.0      hi_d     2035-01-01     2069-12-31
#
#                   time_range  \
# 0      2045010100-2055010100
# 1      2045010100-2055010100
# 2      2055010100-2065010100
# 3      2055010100-2065010100
# 4      2055010100-2065010100
# ...                      ...
# 32555      20350101-20691231
# 32556      20350101-20691231
# 32557      20350101-20691231
# 32558      20350101-20691231
# 32559      20350101-20691231
#
#                                                long_name                units  \
# 0                        Surface temperature (radiative)                    K
# 1                            surface PM2.5 concentration                kg/m3
# 2      Total (convective and large-scale) precipitati...                  m/s
# 3          Pervious day 10.7 cm solar radio flux (F10.7)                 None
# 4                       10.7 cm solar radio flux (F10.7)  10^-22 W m^-2 Hz^-1
# ...                                                  ...                  ...
# 32555                             congelation ice growth               cm/day
# 32556                                  frazil ice growth               cm/day
# 32557                               area tendency thermo                %/day
# 32558                                     basal ice melt               cm/day
# 32559                       grid cell mean ice thickness                    m
#
#        vertical_levels frequency  \
# 0                  1.0    hour_1
# 1                  1.0    hour_1
# 2                  1.0    hour_1
# 3                  1.0    hour_1
# 4                  1.0    hour_1
# ...                ...       ...
# 32555              1.0     day_1
# 32556              1.0     day_1
# 32557              1.0     day_1
# 32558              1.0     day_1
# 32559              1.0     day_1
#
#                                                     path
# 0      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 1      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 2      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 3      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 4      /glade/campaign/cesm/development/wawg/WACCM6-T...
# ...                                                  ...
# 32555  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32556  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32557  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32558  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32559  /glade/campaign/cesm/development/wawg/WACCM6-T...
#
# [32059 rows x 13 columns]

# %% [markdown]
# ## Save the Catalog

# %%
b.save(
    'data/silver-linings-test.csv',
    # Column name including filepath
    path_column_name='path',
    # Column name including variables
    variable_column_name='variable',
    # Data file format - could be netcdf or zarr (in this case, netcdf)
    data_format="netcdf",
    # Which attributes to groupby when reading in variables using intake-esm
    groupby_attrs=["component", "stream", "case"],
    # Aggregations which are fed into xarray when reading in data using intake
    aggregations=[
        {
            "type": "join_existing",
            "attribute_name": "time_range",
            "options": {"dim": "time", "coords": "minimal", "compat": "override"},
        }
    ],
)
# Out:
# Saved catalog location: data/silver-linings-test.json and data/silver-linings-test.csv
# /glade/scratch/dbailey/ipykernel_296679/956542312.py:1: UserWarning: Unable to parse 501 assets/files. A list of these assets can be found in data/invalid_assets_silver-linings-test.csv.
#   b.save(
