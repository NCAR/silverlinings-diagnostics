# %% [markdown]
# # Build the data catalog

# %% [markdown]
# ## Imports

# %%
from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_timeseries

# %% [markdown]
# ## Setup the Builder

# %%
b = Builder(
    # Where to look for model output
    "/glade/campaign/cesm/development/wawg/WACCM6-TSMLT-GEO/SAI1/",
    exclude_patterns=["*/hist/*", "*/rest/*"],
    njobs=-1,
)

# %% [markdown]
# ## Build the Catalog

# %%
b= b.build(parse_cesm_timeseries)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.5s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   8 | elapsed:    3.8s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    5.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 40 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 208 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 568 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 802 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 1072 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 1378 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 1720 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 2098 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 2512 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 2962 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 3448 tasks      | elapsed:   19.6s
# [Parallel(n_jobs=-1)]: Done 3970 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 4528 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 5122 tasks      | elapsed:   26.8s
# [Parallel(n_jobs=-1)]: Done 5752 tasks      | elapsed:   29.5s
# [Parallel(n_jobs=-1)]: Done 6418 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 7120 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Done 7858 tasks      | elapsed:   38.2s
# [Parallel(n_jobs=-1)]: Done 8632 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done 9442 tasks      | elapsed:   45.6s
# [Parallel(n_jobs=-1)]: Done 10288 tasks      | elapsed:   49.1s
# [Parallel(n_jobs=-1)]: Done 11170 tasks      | elapsed:   53.0s
# [Parallel(n_jobs=-1)]: Done 12088 tasks      | elapsed:   57.4s
# [Parallel(n_jobs=-1)]: Done 13042 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 14032 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 15058 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 16120 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 17218 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 18352 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 20204 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 22616 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 25500 out of 25579 | elapsed:  1.9min remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 25579 out of 25579 | elapsed:  1.9min finished
# /glade/u/home/mgrover/.local/lib/python3.9/site-packages/ecgtools/builder.py:179: UserWarning: Unable to parse 84 assets/files. A list of these assets can be found in `.invalid_assets` attribute.
#   self.get_directories().get_filelist()._parse(

# %%
b.df
# Out:
#       component   stream                                             case  \
# 0           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 1           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 2           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 3           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# 4           atm   cam.h4  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.006
# ...         ...      ...                                              ...
# 25574       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 25575       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 25576       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 25577       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
# 25578       ice  cice.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.002
#
#        member_id  variable     start_time       end_time  \
# 0            6.0        TS  2045-01-01T00  2055-01-01T00
# 1            6.0  PM25_SRF  2045-01-01T00  2055-01-01T00
# 2            6.0     PRECT  2055-01-01T00  2065-01-01T00
# 3            6.0     f107p  2055-01-01T00  2065-01-01T00
# 4            6.0      f107  2055-01-01T00  2065-01-01T00
# ...          ...       ...            ...            ...
# 25574        2.0  congel_d     2035-01-01     2069-12-31
# 25575        2.0  frazil_d     2035-01-01     2069-12-31
# 25576        2.0  daidtt_d     2035-01-01     2069-12-31
# 25577        2.0   meltb_d     2035-01-01     2069-12-31
# 25578        2.0      hi_d     2035-01-01     2069-12-31
#
#                   time_range  \
# 0      2045010100-2055010100
# 1      2045010100-2055010100
# 2      2055010100-2065010100
# 3      2055010100-2065010100
# 4      2055010100-2065010100
# ...                      ...
# 25574      20350101-20691231
# 25575      20350101-20691231
# 25576      20350101-20691231
# 25577      20350101-20691231
# 25578      20350101-20691231
#
#                                                long_name                units  \
# 0                        Surface temperature (radiative)                    K
# 1                            surface PM2.5 concentration                kg/m3
# 2      Total (convective and large-scale) precipitati...                  m/s
# 3          Pervious day 10.7 cm solar radio flux (F10.7)                 None
# 4                       10.7 cm solar radio flux (F10.7)  10^-22 W m^-2 Hz^-1
# ...                                                  ...                  ...
# 25574                             congelation ice growth               cm/day
# 25575                                  frazil ice growth               cm/day
# 25576                               area tendency thermo                %/day
# 25577                                     basal ice melt               cm/day
# 25578                       grid cell mean ice thickness                    m
#
#        vertical_levels frequency  \
# 0                  1.0    hour_1
# 1                  1.0    hour_1
# 2                  1.0    hour_1
# 3                  1.0    hour_1
# 4                  1.0    hour_1
# ...                ...       ...
# 25574              1.0     day_1
# 25575              1.0     day_1
# 25576              1.0     day_1
# 25577              1.0     day_1
# 25578              1.0     day_1
#
#                                                     path
# 0      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 1      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 2      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 3      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 4      /glade/campaign/cesm/development/wawg/WACCM6-T...
# ...                                                  ...
# 25574  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 25575  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 25576  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 25577  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 25578  /glade/campaign/cesm/development/wawg/WACCM6-T...
#
# [25495 rows x 13 columns]

# %% [markdown]
# ## Save the Catalog

# %%
b.save(
    'data/silver-linings-test.csv',
    # Column name including filepath
    path_column_name='path',
    # Column name including variables
    variable_column_name='variable',
    # Data file format - could be netcdf or zarr (in this case, netcdf)
    data_format="netcdf",
    # Which attributes to groupby when reading in variables using intake-esm
    groupby_attrs=["component", "stream", "case"],
    # Aggregations which are fed into xarray when reading in data using intake
    aggregations=[
        {
            "type": "join_existing",
            "attribute_name": "time_range",
            "options": {"dim": "time", "coords": "minimal", "compat": "override"},
        }
    ],
)
# Out:
# Saved catalog location: data/silver-linings-test.json and data/silver-linings-test.csv
# /glade/scratch/mgrover/ipykernel_86921/956542312.py:1: UserWarning: Unable to parse 84 assets/files. A list of these assets can be found in data/invalid_assets_silver-linings-test.csv.
#   b.save(
