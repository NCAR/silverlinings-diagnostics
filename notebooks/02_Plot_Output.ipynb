# %% [markdown]
# # Plot the Output

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# ## Read in the Data

# %%
ds = xr.open_dataset('global_average_temperature.nc')

# %% [markdown]
# ## Plot the Output

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.subplot(111)

ds.TREFHT.plot(hue='case')

plt.ylim(285, 295)
# Out:
# (285.0, 295.0)
