# %% [markdown]
# # Build the data catalog

# %% [markdown]
# ## Imports

# %%
from ecgtools import Builder
from ecgtools.parsers.cesm import parse_cesm_timeseries

# %% [markdown]
# ## Setup the Builder

# %%
b = Builder(
    # Where to look for model output
    "/glade/campaign/cesm/development/wawg/WACCM6-TSMLT-GEO/SAI1/",
    exclude_patterns=["*/hist/*", "*/rest/*"],
    njobs=-1,
)

# %% [markdown]
# ## Build the Catalog

# %%
b= b.build(parse_cesm_timeseries)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 60 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:    1.0s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    2.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done   8 out of  10 | elapsed:    4.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    5.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 60 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 168 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 330 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 528 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 762 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 1032 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 1338 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 1680 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 2256 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done 3084 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=-1)]: Done 3984 tasks      | elapsed:   25.4s
# [Parallel(n_jobs=-1)]: Done 4956 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 6000 tasks      | elapsed:   34.9s
# [Parallel(n_jobs=-1)]: Done 7116 tasks      | elapsed:   40.4s
# [Parallel(n_jobs=-1)]: Done 8304 tasks      | elapsed:   46.0s
# [Parallel(n_jobs=-1)]: Done 9564 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 10896 tasks      | elapsed:   57.9s
# [Parallel(n_jobs=-1)]: Done 12300 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 13776 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 15324 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 16944 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 18636 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 20400 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 22236 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 24144 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 26124 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 28176 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 30300 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 32441 out of 32560 | elapsed:  2.6min remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 32560 out of 32560 | elapsed:  2.6min finished
# /glade/work/mgrover/git_repos/ecgtools/ecgtools/builder.py:179: UserWarning: Unable to parse 501 assets/files. A list of these assets can be found in `.invalid_assets` attribute.
#   self.get_directories().get_filelist()._parse(

# %%
b.df
# Out:
#       component  stream                                             case  \
# 0           atm  cam.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.001
# 1           atm  cam.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.001
# 2           atm  cam.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.001
# 3           atm  cam.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.001
# 4           atm  cam.h1  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.001
# ...         ...     ...                                              ...
# 32555       rof  rtm.h0  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.010
# 32556       rof  rtm.h0  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.010
# 32557       rof  rtm.h0  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.010
# 32558       rof  rtm.h0  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.010
# 32559       rof  rtm.h0  b.e21.BW.f09_g17.SSP245-TSMLT-GAUSS-DEFAULT.010
#
#       member_id                       variable  start_time    end_time  \
# 0           001                          ACTNL  2035-01-01  2044-12-31
# 1           001                          ACTNL  2045-01-01  2054-12-31
# 2           001                          ACTNL  2055-01-01  2064-12-31
# 3           001                          ACTNL  2065-01-01  2069-12-30
# 4           001                         ACTREL  2035-01-01  2044-12-31
# ...         ...                            ...         ...         ...
# 32555       010  DIRECT_DISCHARGE_TO_OCEAN_LIQ     2035-01     2070-12
# 32556       010  RIVER_DISCHARGE_OVER_LAND_ICE     2035-01     2070-12
# 32557       010  RIVER_DISCHARGE_OVER_LAND_LIQ     2035-01     2070-12
# 32558       010   TOTAL_DISCHARGE_TO_OCEAN_ICE     2035-01     2070-12
# 32559       010   TOTAL_DISCHARGE_TO_OCEAN_LIQ     2035-01     2070-12
#
#               time_range                                   long_name   units  \
# 0      20350101-20441231            Average Cloud Top droplet number     m-3
# 1      20450101-20541231            Average Cloud Top droplet number     m-3
# 2      20550101-20641231            Average Cloud Top droplet number     m-3
# 3      20650101-20691230            Average Cloud Top droplet number     m-3
# 4      20350101-20441231  Average Cloud Top droplet effective radius  Micron
# ...                  ...                                         ...     ...
# 32555      203501-207012     MOSART direct discharge into ocean: LIQ    m3/s
# 32556      203501-207012                MOSART river basin flow: ICE    m3/s
# 32557      203501-207012                MOSART river basin flow: LIQ    m3/s
# 32558      203501-207012      MOSART total discharge into ocean: ICE    m3/s
# 32559      203501-207012      MOSART total discharge into ocean: LIQ    m3/s
#
#        vertical_levels frequency  \
# 0                  1.0     day_1
# 1                  1.0     day_1
# 2                  1.0     day_1
# 3                  1.0     day_1
# 4                  1.0     day_1
# ...                ...       ...
# 32555              1.0   month_1
# 32556              1.0   month_1
# 32557              1.0   month_1
# 32558              1.0   month_1
# 32559              1.0   month_1
#
#                                                     path
# 0      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 1      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 2      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 3      /glade/campaign/cesm/development/wawg/WACCM6-T...
# 4      /glade/campaign/cesm/development/wawg/WACCM6-T...
# ...                                                  ...
# 32555  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32556  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32557  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32558  /glade/campaign/cesm/development/wawg/WACCM6-T...
# 32559  /glade/campaign/cesm/development/wawg/WACCM6-T...
#
# [32059 rows x 13 columns]

# %% [markdown]
# ## Save the Catalog

# %%
b.save(
    'data/silver-linings-test.csv',
    # Column name including filepath
    path_column_name='path',
    # Column name including variables
    variable_column_name='variable',
    # Data file format - could be netcdf or zarr (in this case, netcdf)
    data_format="netcdf",
    # Which attributes to groupby when reading in variables using intake-esm
    groupby_attrs=["component", "stream", "case"],
    # Aggregations which are fed into xarray when reading in data using intake
    aggregations=[
        {
            "type": "join_existing",
            "attribute_name": "time_range",
            "options": {"dim": "time", "coords": "minimal", "compat": "override"},
        }
    ],
)
# Out:
# Saved catalog location: data/silver-linings-test.json and data/silver-linings-test.csv
# /glade/scratch/mgrover/ipykernel_154224/956542312.py:1: UserWarning: Unable to parse 501 assets/files. A list of these assets can be found in data/invalid_assets_silver-linings-test.csv.
#   b.save(
